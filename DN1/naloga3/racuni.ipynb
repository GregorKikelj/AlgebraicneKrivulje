# %%
from sympy import *
import numpy as np

x, y, z, w, a, b, c, d, e, f, g, h, i = symbols('x y z w a b c d e f g h i')
init_printing()

# %%
def f(x, y):
  return (x**2+y**2)**3-4*x**2*y**2

# %%
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
xp = []
yp = []

for x in tqdm(np.linspace(-1, 1, 5000)):
  for y in np.linspace(-1, 1, 5000):
    if abs(f(x, y)) < 0.0001:
      xp.append(x)
      yp.append(y)
# Out:
# 100%|██████████| 5000/5000 [00:55<00:00, 89.45it/s]

# %%
plt.plot(xp, yp, '.')

# %%
plot_implicit((x**2+y**2)**3-4*x**2*y**2)
